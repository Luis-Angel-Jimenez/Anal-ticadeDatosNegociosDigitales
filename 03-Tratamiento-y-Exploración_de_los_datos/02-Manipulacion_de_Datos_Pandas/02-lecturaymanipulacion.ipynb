# %% [markdown]
# # MANIPULACIÓN Y LECTURA DE DATOS EN PANDAS xd

# %% [markdown]
# ## ¿Para que sirve?

# %% [markdown]
# La carga y lectura de datos en Pandas sirve para importar y manipular datos fácilmente dentro de Python. Es uno de los pasos más importantes cuando trabajas con analisis de datos, ciencia de datos o cualquier proceso relacionado con bases de datos y archivos.

# %% [markdown]
# Asi se importa la libreria de pandas y se hace la lectura de cualquier archivo mencionado en la diapositiva

# %% [markdown]
# `Que es la Manipulacion de Datos`

# %%
import pandas as pd
df = pd.read_csv('./Datasets/linkedin-jobs-usa-modificado.csv')
# Tambien puede ser
# df = pd.read_csv('./Datasets/linkedin-jobs-usa-modificado.sql')
# df = pd.read_csv('./Datasets/linkedin-jobs-usa-modificado.json')
# df = pd.read_csv('./Datasets/linkedin-jobs-usa-modificado.xlsx')

# %% [markdown]
# ### Exploracion: Comandos o Metodos, `head()`, `tail()`, `info()`, `describe`, `dtype` y `shape`

# %% [markdown]
# Ahora para mostrar los primeras filas de el archivo usamos el comando `head`

# %% [markdown]
# |---|
# |---|
# |---|

# %%
df
# Out:
#                                title                   company  \
# 0     Data Analyst - Recent Graduate                    PayPal
# 1     Data Analyst - Recent Graduate                    PayPal
# 2                       Data Analyst                    PayPal
# 3                       Data Analyst                    PayPal
# 4           Entry-Level Data Analyst  The Federal Savings Bank
# ...                              ...                       ...
# 2840             Junior Data Analyst        Iris Software Inc.
# 2841              Data Analyst (SQL)             Marwood Group
# 2842                    Data Analyst        SmartSense by Digi
# 2843                    Data Analyst            Synergy Search
# 2844                    Data Analyst            Insight Global
#
#                                             description onsite_remote  \
# 0     At PayPal (NASDAQ: PYPL), we believe that ever...        onsite
# ...

# %%
df.head()
# Out:
#                             title                   company  \
# 0  Data Analyst - Recent Graduate                    PayPal
# 1  Data Analyst - Recent Graduate                    PayPal
# 2                    Data Analyst                    PayPal
# 3                    Data Analyst                    PayPal
# 4        Entry-Level Data Analyst  The Federal Savings Bank
#
#                                          description onsite_remote  \
# 0  At PayPal (NASDAQ: PYPL), we believe that ever...        onsite
# 1  At PayPal (NASDAQ: PYPL), we believe that ever...        onsite
# 2  At PayPal (NASDAQ: PYPL), we believe that ever...        onsite
# 3  At PayPal (NASDAQ: PYPL), we believe that ever...        onsite
# 4  The Federal Savings Bank, a national bank and ...        onsite
#
#    salary_float                    location  \
# 0       86658.0  Buffalo-Niagara Falls Area
# 1       74052.0                San Jose, CA
# 2       81425.0        Texas, United States
# ...

# %%
df.head(10)
# Out:
#                             title                   company  \
# 0  Data Analyst - Recent Graduate                    PayPal
# 1  Data Analyst - Recent Graduate                    PayPal
# 2                    Data Analyst                    PayPal
# 3                    Data Analyst                    PayPal
# 4        Entry-Level Data Analyst  The Federal Savings Bank
# 5                    Data Analyst                    PayPal
# 6                    Data Analyst                    PayPal
# 7                    Data Analyst                    PayPal
# 8                    Data Analyst           London Approach
# 9                    Data Analyst                    PayPal
#
#                                          description onsite_remote  \
# 0  At PayPal (NASDAQ: PYPL), we believe that ever...        onsite
# 1  At PayPal (NASDAQ: PYPL), we believe that ever...        onsite
# 2  At PayPal (NASDAQ: PYPL), we believe that ever...        onsite
# ...

# %%
print(df.head(20))
# Out:
#                              title                         company  \
# 0   Data Analyst - Recent Graduate                          PayPal
# 1   Data Analyst - Recent Graduate                          PayPal
# 2                     Data Analyst                          PayPal
# 3                     Data Analyst                          PayPal
# 4         Entry-Level Data Analyst        The Federal Savings Bank
# 5                     Data Analyst                          PayPal
# 6                     Data Analyst                          PayPal
# 7                     Data Analyst                          PayPal
# 8                     Data Analyst                 London Approach
# 9                     Data Analyst                          PayPal
# 10                    Data Analyst                          PayPal
# 11  Data Analyst - Recent Graduate                          PayPal
# 12                    Data Analyst                     Motley Rice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2845 entries, 0 to 2844
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          2845 non-null   object
#  1   company        2845 non-null   object
#  2   description    2845 non-null   object
#  3   onsite_remote  2845 non-null   object
#  4   salary_float   2845 non-null   float64
#  5   location       2845 non-null   object
#  6   criteria       2845 non-null   object
#  7   posted_date    2845 non-null   object
#  8   link           2845 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 200.2+ KB

# %%
df.describe()
# Out:
#         salary_float
# count    2845.000000
# mean    75528.560633
# std     34985.578239
# min        23.000000
# 25%     71451.500000
# 50%     84108.500000
# 75%     96004.000000
# max    140000.000000

# %%
df['salary_float'].median()
# Out:
# np.float64(84108.5)

# %% [markdown]
# # `dtype`

# %% [markdown]
# Permite visualizar los tipos de datos de las columnas

# %%
df.dtypes
# Out:
# title             object
# company           object
# description       object
# onsite_remote     object
# salary_float     float64
# location          object
# criteria          object
# posted_date       object
# link              object
# dtype: object

# %% [markdown]
# # `shape`

# %% [markdown]
# Nos da el tamaño del dataframe el primer datos filas y segundo columnas

# %%
df.shape
# Out:
# (2845, 9)

# %%
# Total de Filas del Dataframe
df.shape[0]
# Out:
# 2845

# %%
# Total de Columnas del Dataframe
df.shape[1]
# Out:
# 9

# %% [markdown]
# # `Tail`

# %%
# Muestra los ultimos 5 datos
df.tail()
# Out:
#                     title             company  \
# 2840  Junior Data Analyst  Iris Software Inc.
# 2841   Data Analyst (SQL)       Marwood Group
# 2842         Data Analyst  SmartSense by Digi
# 2843         Data Analyst      Synergy Search
# 2844         Data Analyst      Insight Global
#
#                                             description onsite_remote  \
# 2840  Iris's client, one of the world's largest fina...        hybrid
# 2841  The Marwood Group (Marwood) is a leading healt...        hybrid
# 2842  Join a high-performing, tight-knit team at a f...        hybrid
# 2843  Nashville (Berry Hill) based company looking t...        hybrid
# 2844  Overview - Minimum 5 years in a quantitative d...        hybrid
#
#       salary_float                         location  \
# 2840       93219.5             Texas, United States
# 2841       85000.0  New York City Metropolitan Area
# 2842       76407.5                    Mishawaka, IN
# ...

# %%
df.tail(10)
# Out:
#                     title                company  \
# 2835  Junior Data Analyst                Infosys
# 2836         Data Analyst            Gridiron IT
# 2837         Data Analyst  Parkave Capital Group
# 2838         Data Analyst       Agility Partners
# 2839         Data Analyst              Frostbite
# 2840  Junior Data Analyst     Iris Software Inc.
# 2841   Data Analyst (SQL)          Marwood Group
# 2842         Data Analyst     SmartSense by Digi
# 2843         Data Analyst         Synergy Search
# 2844         Data Analyst         Insight Global
#
#                                             description onsite_remote  \
# 2835  Currently, we are seeking a Junior Data Analys...        hybrid
# 2836  Gridiron IT is seeking a Data Analyst local to...        hybrid
# 2837  Parkave is looking to hire a passionate data s...        hybrid
# 2838  About this RoleAgility Partners is working wit...        hybrid
# ...

# %%
# Muestra los nombres de las columnas 
df.columns
# Out:
# Index(['title', 'company', 'description', 'onsite_remote', 'salary_float',
#        'location', 'criteria', 'posted_date', 'link'],
#       dtype='object')

# %%
# Muestra donde comienza, donde termina y de en cuanto en cuanto va
df.index
# Out:
# RangeIndex(start=0, stop=2845, step=1)
